# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../data/interim/batdongsan_com_vn(1).csv')
df_2 = pd.read_csv('../data/interim/batdongsan_com_vn(2).csv')
df_3 = pd.read_csv('../data/interim/muaban_net.csv')

# %% [markdown]
# ### Merge datasets

# %%
cols_in_common = [
    'price', 'area', 'n_bedrooms', 'n_bathrooms', 'property_type', 'address',
    'legal_docs', 'city/district', 'facing_direction', 'front_width'
]
df = pd.concat([df_1[cols_in_common], df_2[cols_in_common], df_3[cols_in_common]], axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28991 entries, 0 to 5413
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             26454 non-null  float64
#  1   area              28989 non-null  float64
#  2   n_bedrooms        17209 non-null  float64
#  3   n_bathrooms       16374 non-null  float64
#  4   property_type     28991 non-null  object
#  5   address           28991 non-null  object
#  6   legal_docs        25987 non-null  object
#  7   city/district     28991 non-null  object
#  8   facing_direction  12603 non-null  object
#  9   front_width       16648 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 2.4+ MB

# %% [markdown]
# ### Use SQL /visualization to inspect data
