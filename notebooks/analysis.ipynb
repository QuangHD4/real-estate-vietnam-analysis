# %%
import pandas as pd

# Load the dataset from the CSV file, excluding the "description" column
df = pd.read_csv('real_estate_data copy.csv').drop(columns=['description'], errors='ignore')

# %%
# Print the first few lines of the dataset
print("First few lines:")
df.head()
# Out:
# First few lines:
#      price      area n_bedrooms n_bathrooms           legal interior  \
# 0   3,9 tỷ    150 m²        NaN         NaN  Sổ đỏ/ Sổ hồng      NaN
# 1    29 tỷ  118,5 m²    3 phòng     2 phòng  Sổ đỏ/ Sổ hồng  Cơ bản.
# 2    29 tỷ  118,5 m²    3 phòng     2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ
# 3  14,9 tỷ     42 m²    7 phòng     5 phòng  Sổ đỏ/ Sổ hồng      NaN
# 4    39 tỷ    612 m²        NaN         NaN             NaN      NaN
#
#   facing_direction balcony_direction front_width front_road_width   latitude  \
# 0             Đông               NaN         6 m             10 m  20.777148
# 1              NaN               NaN         NaN              NaN  10.784310
# 2        Tây - Nam        Đông - Nam         NaN              NaN  10.783668
# 3              Nam               Nam       3,5 m             15 m  20.971526
# 4              NaN               NaN         NaN              NaN  10.850192
#
#     longitude  verified              location
# ...

# %%
print(df["price"].count())
# Out:
# 4999

# %%
# Print dataset info
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              4999 non-null   object
#  1   area               4999 non-null   object
#  2   n_bedrooms         1994 non-null   object
#  3   n_bathrooms        1935 non-null   object
#  4   legal              4962 non-null   object
#  5   interior           1663 non-null   object
#  6   facing_direction   2134 non-null   object
#  7   balcony_direction  702 non-null    object
#  8   front_width        3719 non-null   object
#  9   front_road_width   3505 non-null   object
#  10  latitude           4999 non-null   float64
#  11  longitude          4999 non-null   float64
#  12  verified           5000 non-null   int64
#  13  location           5000 non-null   object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 547.0+ KB

# %%
# Print descriptive statistics of the dataset
print("\nDescriptive Statistics:")
df.describe(include="all")
# Out:
# Descriptive Statistics:
#          price    area n_bedrooms n_bathrooms           legal interior  \
# count     4999    4999       1994        1935            4962     1663
# unique     997    1570         35          32              84      144
# top     4,5 tỷ  100 m²    2 phòng     2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ
# freq        43     177        472         619            3187      702
# mean       NaN     NaN        NaN         NaN             NaN      NaN
# std        NaN     NaN        NaN         NaN             NaN      NaN
# min        NaN     NaN        NaN         NaN             NaN      NaN
# 25%        NaN     NaN        NaN         NaN             NaN      NaN
# 50%        NaN     NaN        NaN         NaN             NaN      NaN
# 75%        NaN     NaN        NaN         NaN             NaN      NaN
# max        NaN     NaN        NaN         NaN             NaN      NaN
#
#        facing_direction balcony_direction front_width front_road_width  \
# ...
